# %% [markdown]
# # install package
# Install myMLpackage from github repo `pip install git+https://github.com/statisticsguru1/myMLpackage.git`

# %%
pip install git+https://github.com/statisticsguru1/myMLpackage.git
# Out:
# ...
#   Cloning https://github.com/statisticsguru1/myMLpackage.git to /tmp/pip-req-build-j5fe_s_q
#   Running command git clone --filter=blob:none --quiet https://github.com/statisticsguru1/myMLpackage.git /tmp/pip-req-build-j5fe_s_q
#   Resolved https://github.com/statisticsguru1/myMLpackage.git to commit 4c23a4ce6983f505ed9964f4e400d968cbc08109
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.5/160.5 kB 4.1 MB/s eta 0:00:00a 0:00:01
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 486.1/486.1 kB 13.3 MB/s eta 0:00:0000:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.8/106.8 kB 5.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.8/21.8 MB 54.6 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 73.6 MB/s eta 0:00:00:00:010:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.1/8.1 MB 73.6 MB/s eta 0:00:00:00:0100:01
# ...

# %% [markdown]
# # Import package modules

# %% [markdown]
# this imports automation class module and general utility tools

# %%
import myMLpackage                                               
from myMLpackage import automation_class as ac
from myMLpackage import general_utility as gu

# %% [markdown]
# # Load experimental data
# This loads in built data `heart disease` and prints a sample data

# %%
data=gu.load_experimental_dataset('heart')
data['target'] = data['target'].replace({1: 'Heart disease', 0: 'No Heart disease'})
data.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal         target
# 0   0     1  Heart disease
# 1   0     2  Heart disease
# 2   0     2  Heart disease
# 3   0     2  Heart disease
# 4   0     2  Heart disease

# %% [markdown]
# # Print data info

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    object
# dtypes: float64(1), int64(12), object(1)
# memory usage: 33.3+ KB

# %% [markdown]
# # Initialize the automation class

# %%
model=ac.Modelling(data,'target')
# Out:
# <style type="text/css">
# #T_11426_row9_col1, #T_11426_row11_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_11426">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_11426_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_11426_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_11426_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_11426_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_11426_row0_col1" class="data row0 col1" >7468</td>
#     </tr>
#     <tr>
#       <th id="T_11426_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_11426_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_11426_row1_col1" class="data row1 col1" >target</td>
#     </tr>
#     <tr>
#       <th id="T_11426_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %% [markdown]
# # See model configuration

# %%
model.model_configs_info
# Out:
#                     Description                                  Value
# 0                    Session id                                   8814
# 1                        Target                                 target
# 2                   Target type                                 Binary
# 3                Target mapping  Heart disease: 0, No Heart disease: 1
# 4           Original data shape                              (303, 14)
# 5        Transformed data shape                              (292, 14)
# 6   Transformed train set shape                              (201, 14)
# 7    Transformed test set shape                               (91, 14)
# 8              Numeric features                                     13
# 9                    Preprocess                                   True
# 10              Imputation type                                   None
# 11              Remove outliers                                   True
# ...

# %% [markdown]
# # see data information

# %%
model.calculate_variable_info()
# Out:
#          Data Type  Unique Values Count  Missing Values Count  \
# age          int64                   41                     0
# sex          int64                    2                     0
# cp           int64                    4                     0
# trestbps     int64                   49                     0
# chol         int64                  152                     0
# fbs          int64                    2                     0
# restecg      int64                    3                     0
# thalach      int64                   91                     0
# exang        int64                    2                     0
# oldpeak    float64                   40                     0
# slope        int64                    3                     0
# ca           int64                    5                     0
# thal         int64                    4                     0
# target      object                    2                     0
#
# ...

# %% [markdown]
# # Model type

# %% [markdown]
# Based on the target variable dtype the class chose a classification set up

# %%
model.determine_model_type()
# Out:
# 'classification'

# %% [markdown]
# graph a countplot of the target

# %%
model.plot_countplot()
# Out:
# <module 'matplotlib.pyplot' from '/opt/conda/lib/python3.10/site-packages/matplotlib/pyplot.py'>

# %%
model.plot_correlation_matrix()
# Out:
# <module 'matplotlib.pyplot' from '/opt/conda/lib/python3.10/site-packages/matplotlib/pyplot.py'>

# %% [markdown]
# # model comparison
# The best model is logistic

# %%
model.model_comparisons
# Out:
#                                     Model  Accuracy     AUC  Recall   Prec.  \
# rf               Random Forest Classifier    0.8262  0.8952  0.8262  0.8336
# xgboost         Extreme Gradient Boosting    0.8169  0.8738  0.8169  0.8218
# ridge                    Ridge Classifier    0.8160  0.8715  0.8160  0.8278
# lda          Linear Discriminant Analysis    0.8160  0.8698  0.8160  0.8278
# qda       Quadratic Discriminant Analysis    0.8119  0.8678  0.8119  0.8200
# catboost              CatBoost Classifier    0.8119  0.9065  0.8119  0.8182
# nb                            Naive Bayes    0.8115  0.8797  0.8115  0.8263
# et                 Extra Trees Classifier    0.8028  0.8853  0.8028  0.8120
# lightgbm  Light Gradient Boosting Machine    0.8028  0.8762  0.8028  0.8086
# gbc          Gradient Boosting Classifier    0.7981  0.8665  0.7981  0.8012
# lr                    Logistic Regression    0.7972  0.8722  0.7972  0.8086
# ...

# %% [markdown]
# # the best model

# %%
model.tuned_model
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='sqrt',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_samples_leaf=1,
#                        min_samples_split=2, min_weight_fraction_leaf=0.0,
#                        monotonic_cst=None, n_estimators=100, n_jobs=-1,
#                        oob_score=False, random_state=8814, verbose=0,
#                        warm_start=False)

# %% [markdown]
# # performance of the best model after parameter tuning

# %%
model.tuned_model_performance
# Out:
#       Accuracy     AUC  Recall   Prec.      F1   Kappa     MCC
# Fold
# 0       0.8182  0.8917  0.8182  0.8263  0.8151  0.6271  0.6383
# 1       0.7727  0.8250  0.7727  0.7731  0.7713  0.5378  0.5401
# 2       0.9524  0.9727  0.9524  0.9563  0.9522  0.9041  0.9083
# 3       0.8095  0.9455  0.8095  0.8603  0.8004  0.6111  0.6633
# 4       0.8095  0.8000  0.8095  0.8196  0.8069  0.6147  0.6264
# 5       0.8095  0.9091  0.8095  0.8228  0.8087  0.6216  0.6331
# 6       0.7143  0.8545  0.7143  0.7143  0.7143  0.4273  0.4273
# 7       0.7143  0.9074  0.7143  0.7143  0.7074  0.4000  0.4082
# 8       0.9524  0.9815  0.9524  0.9560  0.9519  0.9014  0.9058
# 9       0.8571  0.9722  0.8571  0.8585  0.8558  0.7042  0.7077
# Mean    0.8210  0.9060  0.8210  0.8302  0.8184  0.6349  0.6459
# Std     0.0783  0.0606  0.0783  0.0799  0.0794  0.1604  0.1602

# %% [markdown]
# # graph model results

# %%
model.graph_results()

# %% [markdown]
# # perform prediction on a new data

# %%
model.prediction(data)
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal            target  prediction_label  prediction_score
# ...

# %% [markdown]
# # use  help() to explore other methods and functions

# %%
help(ac.Modelling)
# Out:
# Help on class Modelling in module myMLpackage.automation_class.automation_class:
#
# class Modelling(builtins.object)
# ...
